# %% [markdown]
# <img src="https://www.th-koeln.de/img/logo.svg" style="float:right;" width="200">

# %% [markdown]
# ##### 7th exercise: <font color="#C70039">Work with Variational Autoencoders (Generative Model)</font>
# * Course: AML
# * Lecturer: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Author of notebook: <a href="https://www.gernotheisenberg.de/">Gernot Heisenberg</a>
# * Date:   29.10.2023
# * Student: Max Hammer
# * Immatriculation ID: 11153562
# <img src="https://miro.medium.com/max/848/1*6uuK7GpIbfTb-0chqFwXXw.png" style="float: center;" width="400">
#
# ---------------------------------
# **GENERAL NOTE 1**:
# Please make sure you are reading the entire notebook, since it contains a lot of information on your tasks (e.g. regarding the set of certain paramaters or a specific computational trick), and the written mark downs as well as comments contain a lot of information on how things work together as a whole.
#
# **GENERAL NOTE 2**:
# * Please, when commenting source code, just use English language only.
# * When describing an observation please use English language, too.
# * This applies to all exercises throughout this course.
#
# ---------------------------------
#
# ### <font color="ce33ff">DESCRIPTION</font>:
# A Variational Autoencoder (VAE), instead of compressing its input image into a fixed code in the latent space (as the classic autoencoder does), turns the input image into the parameters of a statistical distribution: a mean and a variance.
#
# This implies / imputes that the input image has been generated by a statistical process and that the randomness of this process should be taken into accounting during encoding and decoding.
#
# The VAE then uses the mean and variance parameters to randomly sample one element of that distribution, and decodes that element back to the original input.
#
# The stochasticity of this process improves robustness and forces the latent space to encode meaningful representations everywhere: every point sampled in the latent space is decoded to a valid output.
#
#
# ---------------------------------
#
# ### <font color="FFC300">TASKS</font>:
# The tasks that you need to work on within this notebook are always indicated below as bullet points.
# If a task is more challenging and consists of several steps, this is indicated as well.
# Make sure you have worked down the task list and commented your doings.
# This should be done by using markdown.<br>
# <font color=red>Make sure you don't forget to specify your name and your matriculation number in the notebook.</font>
#
# **YOUR TASKS in this exercise are as follows**:
# 1. import the notebook to Google Colab or use your local machine.
# 2. make sure you specified you name and your matriculation number in the header below my name and date.
#     * set the date too and remove mine.
# 3. read the entire notebook carefully
#     * add comments whereever you feel it necessary for better understanding
#     * run the notebook for the first time.
#     * try to understand each single step.
# 4. the notebooks code, especially keras is sometimes utilized a bit cumbersome. Try to optimize the code where you feel necessary.
# 5. experiment with different hyperparameters (search for the keyword 'task')
# 6. describe the three different loss curve plots. What do they show? Is this what you expected?
# 7. the main task is to visualize the latent space, the encoder has created. If you set high dimensions for the latent dim you can use T_SNE (plot 4).
# 8. describe the latent space with respect to its structure. Is this what you expected from a VAE?
# ---------------------------------

# %% [markdown]
# ### VAEs
# This code demonstrates a VAE using the MNIST dataset.
# Just like a regular autoencoder a VAE returns an array (image) of same dimensions as the input but variation can be introduced by tweaking the so-called latent vector.

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from   tensorflow.keras import layers, models, losses, metrics, optimizers
from   tensorflow.keras.datasets import mnist
# Out:
# /Users/max/Documents/GitHub/AML/.venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ### Model: "Encoder"
# Create an encoder model with the following properties:

# %%
# _____________________________________________________________________________
#  Layer (type)                 Output Shape         Activation     Input      
# =============================================================================
#  encoder_input (InputLayer)       [(None, 28, 28, 1)]  None           
#  encoder_flatten (Flatten)        (None, 784)          None           enc_input
#  encoder_dense_1 (Dense)          (None, 2000)         ReLU           enc_flatten
#  encoder_dense_2 (Dense)          (None, 256)          ReLU           enc_dense_1
#  z_mean (Dense)                   (None, 2)            None           enc_dense_2
#  z_log_var (Dense)                (None, 2)            None           enc_dense_2

encoder_input = layers.Input(shape=(28,28,1), dtype='float32')
encoder_flatten = layers.Flatten(name = 'flat')(encoder_input)
encoder_dense_1 = layers.Dense(units = 2000, activation = 'relu', name = 'dense_1')(encoder_flatten)
encoder_dense_2 = layers.Dense(units = 256, activation = 'relu', name = 'dense_2')(encoder_dense_1)
z_mean = layers.Dense(units = 2, name = 'latent_mean')(encoder_dense_2)
z_log_var  = layers.Dense(units = 2, name = 'latent_log_var')(encoder_dense_2)

encoder = models.Model(inputs = encoder_input, outputs = (z_mean, z_log_var), name = 'encoder')

encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  flat (Flatten)              (None, 784)                  0         ['input_1[0][0]']
#
#  dense_1 (Dense)             (None, 2000)                 1570000   ['flat[0][0]']
#
#  dense_2 (Dense)             (None, 256)                  512256    ['dense_1[0][0]']
#
#  latent_mean (Dense)         (None, 2)                    514       ['dense_2[0][0]']
#
#  latent_log_var (Dense)      (None, 2)                    514       ['dense_2[0][0]']
#
# ==================================================================================================
# Total params: 2083284 (7.95 MB)
# Trainable params: 2083284 (7.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %% [markdown]
# ### Model: "decoder"
# Create a decoder model with the following properties:

# %%
# _____________________________________________________________________________
#  Layer (type)                Output Shape          Activation     Input
# =============================================================================
#  decoder_input (InputLayer)      [(None, 2)]           None
#  decoder_dense_1 (Dense)         (None, 256)           ReLU           dec_input
#  decoder_dense_2 (Dense)         (None, 2000)          ReLU           dec_dense_1
#  decoder_dense_3 (Dense)         (None, 784)           Sigmoid        dec_dense_2
#  img_out (Reshape)               (None, 28, 28, 1)     None           des_dense_3

decoder_input = layers.Input(shape=(2,), dtype='float32')
decoder_dense_1 = layers.Dense(units = 256, activation = 'relu', name = 'dec_dense_1')(decoder_input)
decoder_dense_2 = layers.Dense(units = 2000, activation = 'relu', name = 'dec_dense_2')(decoder_dense_1)
decoder_dense_3 = layers.Dense(units = 784, activation = 'sigmoid', name = 'dec_dense_3')(decoder_dense_2)
img_out = layers.Reshape((28,28,1), name = 'img_out')(decoder_dense_3)

decoder = models.Model(inputs = decoder_input, outputs = img_out, name = 'decoder')
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dec_dense_1 (Dense)         (None, 256)               768
#
#  dec_dense_2 (Dense)         (None, 2000)              514000
#
#  dec_dense_3 (Dense)         (None, 784)               1568784
#
#  img_out (Reshape)           (None, 28, 28, 1)         0
#
# =================================================================
# Total params: 2083552 (7.95 MB)
# Trainable params: 2083552 (7.95 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
# class 'latent_sampling', which subclasses layers.Layer.
# The class should perform the reparameterisation trick in its .call() method.

'''---------------------------------------------------------------------------'''
# Reparameterization Trick: z = mean + epsilon * exp(ln(variance) * 0.5)
# epsilon = N(0,1), a unit normal with same dims as mean and variance
'''---------------------------------------------------------------------------'''
class latent_sampling(layers.Layer):
    
  def call(self, z_mean, z_log_var):
    tf.keras.layers.Layer(trainable = True)
    self.batch = tf.shape(z_mean)[0]
    self.dim = tf.shape(z_mean)[1]
    self.epsilon = tf.keras.backend.random_normal(shape=(self.batch, self.dim))
    self.z =  z_mean + self.epsilon * tf.exp(z_log_var * 0.5)
    
    return self.z

# %%
### The 'VAE' Class. 
### The __init__ method—which will set up the layers and submodels—and the call() method.

class VAE(tf.keras.Model):
    """
    A Keras Model that implements a Variational Autoencoder. Model properties
    should include the encoder and decoder models, a sampling layer, and the
    number of latent variables in the encoded space.
    """
    def __init__(self, latent_dim, encoder, decoder):
        super(VAE, self).__init__()
        """
        Take in model properties and assign them to self.
        """
        self.latent_dim = latent_dim
        self.encoder = encoder
        self.sampling = latent_sampling()
        self.decoder = decoder
        
    def encode(self, x):
        """
        Method that applies the encoder model to input data. Returns the mean
        and ln(variance) of the encoded variables.
        """
        mean, logvar = self.encoder(x)
        return mean, logvar

    def decode(self, z):
        """
        Method that applies the decoder model to a set of encoded variables.
        Returns the generated images from the encoded data.
        """
        x_hat = self.decoder(z)
        return x_hat

    def kl_loss(self, mean, logvar):
        """
        Method that calculates the Kullback-Liebler divergence between the
        posterier distribution, N(mean, variance), and the prior, N(0,1).
        Can be added to the model as a loss or metric, using self.add_loss and
        self.add_metric
        """

        # Calculate the element wise KL divergence
        kl = -0.5 * (1 + logvar - tf.square(mean) - tf.exp(logvar))
        # Sum up the divergence of all the variables in each data sample
        kl = tf.reduce_sum(kl, axis=1)
        # Average the divergence across all samples in the batch
        kl = tf.reduce_mean(kl)
        return kl

    def call(self, inputs):
        """
        Apply the encoder, sampling layer and decoder to the input data. Add
        the kl divergence to the model losses and metrics. Return the generated
        image.
        """
        z_mean, z_log_var = self.encoder(inputs)
        sampled_output = self.sampling(z_mean, z_log_var)
        output = self.decoder(sampled_output)
        self.add_loss(self.kl_loss(z_mean, z_log_var))
        self.add_metric(self.kl_loss(z_mean, z_log_var), name = 'kl_loss_metric')
        return output

# %%
# Modified loss function for the model. The standard binary cross entropy
# takes a mean over all pixels in all images, but the VAE needs the
# reconstruction loss to be the sum of the pixel-wise losses, averaged over
# samples in the batch. Otherwise the reconstruction loss is becoming too small.

def recon_loss(y_true, y_pred):
    loss = tf.reduce_sum(losses.binary_crossentropy(y_true, y_pred),axis=(1, 2))
    return loss

# %%
# Create the VAE model, using your encoder and decoder models. 
# Compile the model with appropriate optimizer settings, losses and metrics.
'''
(TASK: don't be afraid to experiment with different settings here (e.g. latent_dim))
'''
autoencoder = VAE(latent_dim = 4, encoder = encoder, decoder = decoder)

# Default learning rate, optimizer = nAdam.
autoencoder.compile(tf.keras.optimizers.Nadam(),loss = recon_loss,
                    metrics = [recon_loss, 'accuracy'])
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Nadam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Nadam`.

# %%
# Load the MNIST data set
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data()

# Function to preprocess the data 
def preprocessing(image):
    image =  tf.expand_dims(image, -1)
    image =  tf.image.random_flip_left_right(image)
    image  = tf.image.convert_image_dtype(image, 'float32')

    return image, image

# Slice off the training data
dataset = tf.data.Dataset.from_tensor_slices(x_train)

# Preparing the data for training 
final_dataset = dataset.shuffle(1000).batch(64, drop_remainder=True).map(preprocessing)

# %% [markdown]
# ### Train the model
# Train the model on the images from the training set until the losses converge.
# "history = model.fit" allows for storing the training and validation losses in a dictionary so they can be visualized later.

# %%
history = autoencoder.fit(final_dataset, batch_size = 256, epochs = 100)
history.history.keys()
# Out:
# Epoch 1/100
# 937/937 [==============================] - 18s 18ms/step - loss: 177.8190 - recon_loss: 172.7944 - accuracy: 0.7932 - kl_loss_metric: 5.0248
# Epoch 2/100
# 937/937 [==============================] - 16s 17ms/step - loss: 164.4914 - recon_loss: 159.0899 - accuracy: 0.7943 - kl_loss_metric: 5.4015
# Epoch 3/100
# 937/937 [==============================] - 16s 18ms/step - loss: 161.6017 - recon_loss: 155.9600 - accuracy: 0.7942 - kl_loss_metric: 5.6416
# Epoch 4/100
# 937/937 [==============================] - 15s 16ms/step - loss: 159.9899 - recon_loss: 154.2021 - accuracy: 0.7944 - kl_loss_metric: 5.7879
# Epoch 5/100
# 937/937 [==============================] - 16s 17ms/step - loss: 158.7958 - recon_loss: 152.9151 - accuracy: 0.7946 - kl_loss_metric: 5.8808
# Epoch 6/100
# 937/937 [==============================] - 16s 17ms/step - loss: 157.6500 - recon_loss: 151.6574 - accuracy: 0.7949 - kl_loss_metric: 5.9924
# Epoch 7/100
# 937/937 [==============================] - 15s 16ms/step - loss: 156.4324 - recon_loss: 150.3560 - accuracy: 0.7953 - kl_loss_metric: 6.0763
# Epoch 8/100
# 937/937 [==============================] - 15s 16ms/step - loss: 155.1990 - recon_loss: 148.9834 - accuracy: 0.7957 - kl_loss_metric: 6.2155
# Epoch 9/100
# 937/937 [==============================] - 15s 16ms/step - loss: 154.2257 - recon_loss: 147.9294 - accuracy: 0.7962 - kl_loss_metric: 6.2964
# Epoch 10/100
# 937/937 [==============================] - 15s 16ms/step - loss: 153.4234 - recon_loss: 147.0092 - accuracy: 0.7964 - kl_loss_metric: 6.4141
# Epoch 11/100
# 937/937 [==============================] - 15s 16ms/step - loss: 152.5779 - recon_loss: 146.0717 - accuracy: 0.7967 - kl_loss_metric: 6.5062
# Epoch 12/100
# 937/937 [==============================] - 15s 17ms/step - loss: 151.8728 - recon_loss: 145.3303 - accuracy: 0.7970 - kl_loss_metric: 6.5425
# Epoch 13/100
# 937/937 [==============================] - 16s 17ms/step - loss: 151.2190 - recon_loss: 144.5851 - accuracy: 0.7973 - kl_loss_metric: 6.6339
# Epoch 14/100
# 937/937 [==============================] - 15s 16ms/step - loss: 150.7664 - recon_loss: 144.0899 - accuracy: 0.7974 - kl_loss_metric: 6.6765
# Epoch 15/100
# 937/937 [==============================] - 16s 17ms/step - loss: 150.1300 - recon_loss: 143.4066 - accuracy: 0.7976 - kl_loss_metric: 6.7234
# Epoch 16/100
# 937/937 [==============================] - 16s 17ms/step - loss: 149.9031 - recon_loss: 143.1543 - accuracy: 0.7976 - kl_loss_metric: 6.7487
# Epoch 17/100
# 937/937 [==============================] - 16s 17ms/step - loss: 149.3868 - recon_loss: 142.5842 - accuracy: 0.7978 - kl_loss_metric: 6.8025
# Epoch 18/100
# 937/937 [==============================] - 17s 18ms/step - loss: 149.0403 - recon_loss: 142.2085 - accuracy: 0.7979 - kl_loss_metric: 6.8318
# Epoch 19/100
# 937/937 [==============================] - 16s 17ms/step - loss: 148.5788 - recon_loss: 141.7325 - accuracy: 0.7980 - kl_loss_metric: 6.8462
# Epoch 20/100
# 937/937 [==============================] - 17s 18ms/step - loss: 148.2320 - recon_loss: 141.3243 - accuracy: 0.7980 - kl_loss_metric: 6.9076
# Epoch 21/100
# 937/937 [==============================] - 17s 18ms/step - loss: 148.0358 - recon_loss: 141.1252 - accuracy: 0.7981 - kl_loss_metric: 6.9107
# Epoch 22/100
# 937/937 [==============================] - 17s 18ms/step - loss: 147.8283 - recon_loss: 140.8849 - accuracy: 0.7981 - kl_loss_metric: 6.9435
# Epoch 23/100
# 937/937 [==============================] - 18s 19ms/step - loss: 147.6742 - recon_loss: 140.7159 - accuracy: 0.7981 - kl_loss_metric: 6.9582
# Epoch 24/100
# 937/937 [==============================] - 17s 19ms/step - loss: 147.2814 - recon_loss: 140.3182 - accuracy: 0.7983 - kl_loss_metric: 6.9633
# Epoch 25/100
# 937/937 [==============================] - 17s 18ms/step - loss: 147.0234 - recon_loss: 140.0402 - accuracy: 0.7984 - kl_loss_metric: 6.9831
# Epoch 26/100
# 937/937 [==============================] - 17s 18ms/step - loss: 146.8221 - recon_loss: 139.8065 - accuracy: 0.7984 - kl_loss_metric: 7.0156
# Epoch 27/100
# 937/937 [==============================] - 17s 18ms/step - loss: 146.8279 - recon_loss: 139.8227 - accuracy: 0.7984 - kl_loss_metric: 7.0050
# Epoch 28/100
# 937/937 [==============================] - 17s 18ms/step - loss: 146.6086 - recon_loss: 139.5604 - accuracy: 0.7984 - kl_loss_metric: 7.0483
# Epoch 29/100
# 937/937 [==============================] - 16s 18ms/step - loss: 146.3270 - recon_loss: 139.2602 - accuracy: 0.7985 - kl_loss_metric: 7.0670
# Epoch 30/100
# 937/937 [==============================] - 16s 17ms/step - loss: 146.1366 - recon_loss: 139.0586 - accuracy: 0.7985 - kl_loss_metric: 7.0781
# Epoch 31/100
# 937/937 [==============================] - 17s 18ms/step - loss: 146.1278 - recon_loss: 139.0591 - accuracy: 0.7985 - kl_loss_metric: 7.0687
# Epoch 32/100
# 937/937 [==============================] - 18s 19ms/step - loss: 145.9490 - recon_loss: 138.8591 - accuracy: 0.7985 - kl_loss_metric: 7.0899
# Epoch 33/100
# 937/937 [==============================] - 17s 18ms/step - loss: 145.9264 - recon_loss: 138.8054 - accuracy: 0.7986 - kl_loss_metric: 7.1210
# Epoch 34/100
# 937/937 [==============================] - 16s 18ms/step - loss: 145.4617 - recon_loss: 138.3150 - accuracy: 0.7987 - kl_loss_metric: 7.1467
# Epoch 35/100
# 937/937 [==============================] - 17s 18ms/step - loss: 145.4655 - recon_loss: 138.3279 - accuracy: 0.7987 - kl_loss_metric: 7.1376
# Epoch 36/100
# 937/937 [==============================] - 17s 18ms/step - loss: 145.2567 - recon_loss: 138.0736 - accuracy: 0.7987 - kl_loss_metric: 7.1831
# Epoch 37/100
# 937/937 [==============================] - 16s 18ms/step - loss: 145.2517 - recon_loss: 138.0889 - accuracy: 0.7987 - kl_loss_metric: 7.1628
# Epoch 38/100
# 937/937 [==============================] - 16s 17ms/step - loss: 145.5751 - recon_loss: 138.3969 - accuracy: 0.7986 - kl_loss_metric: 7.1783
# Epoch 39/100
# 937/937 [==============================] - 16s 17ms/step - loss: 145.0314 - recon_loss: 137.8474 - accuracy: 0.7987 - kl_loss_metric: 7.1839
# Epoch 40/100
# 937/937 [==============================] - 16s 17ms/step - loss: 144.9803 - recon_loss: 137.7971 - accuracy: 0.7987 - kl_loss_metric: 7.1833
# Epoch 41/100
# 937/937 [==============================] - 16s 17ms/step - loss: 145.3866 - recon_loss: 138.1860 - accuracy: 0.7986 - kl_loss_metric: 7.2006
# Epoch 42/100
# 937/937 [==============================] - 16s 17ms/step - loss: 144.8363 - recon_loss: 137.6305 - accuracy: 0.7988 - kl_loss_metric: 7.2059
# Epoch 43/100
# 937/937 [==============================] - 16s 17ms/step - loss: 144.7837 - recon_loss: 137.5407 - accuracy: 0.7988 - kl_loss_metric: 7.2430
# Epoch 44/100
# 937/937 [==============================] - 16s 17ms/step - loss: 144.4749 - recon_loss: 137.2180 - accuracy: 0.7989 - kl_loss_metric: 7.2568
# Epoch 45/100
# 937/937 [==============================] - 16s 17ms/step - loss: 144.8045 - recon_loss: 137.5566 - accuracy: 0.7988 - kl_loss_metric: 7.2479
# Epoch 46/100
# 937/937 [==============================] - 17s 18ms/step - loss: 144.7518 - recon_loss: 137.4785 - accuracy: 0.7988 - kl_loss_metric: 7.2733
# Epoch 47/100
# 937/937 [==============================] - 17s 18ms/step - loss: 144.3566 - recon_loss: 137.0856 - accuracy: 0.7990 - kl_loss_metric: 7.2710
# Epoch 48/100
# 937/937 [==============================] - 18s 19ms/step - loss: 144.1981 - recon_loss: 136.9229 - accuracy: 0.7990 - kl_loss_metric: 7.2750
# Epoch 49/100
# 937/937 [==============================] - 22s 24ms/step - loss: 143.7132 - recon_loss: 136.4252 - accuracy: 0.7990 - kl_loss_metric: 7.2879
# Epoch 50/100
# 937/937 [==============================] - 23s 25ms/step - loss: 144.0509 - recon_loss: 136.7775 - accuracy: 0.7989 - kl_loss_metric: 7.2735
# Epoch 51/100
# 937/937 [==============================] - 23s 24ms/step - loss: 143.9726 - recon_loss: 136.6738 - accuracy: 0.7990 - kl_loss_metric: 7.2987
# Epoch 52/100
# 937/937 [==============================] - 23s 25ms/step - loss: 143.9113 - recon_loss: 136.6167 - accuracy: 0.7989 - kl_loss_metric: 7.2946
# Epoch 53/100
# 937/937 [==============================] - 25s 27ms/step - loss: 143.6524 - recon_loss: 136.3668 - accuracy: 0.7990 - kl_loss_metric: 7.2857
# Epoch 54/100
# 937/937 [==============================] - 25s 27ms/step - loss: 143.6750 - recon_loss: 136.3562 - accuracy: 0.7990 - kl_loss_metric: 7.3189
# Epoch 55/100
# 937/937 [==============================] - 24s 25ms/step - loss: 143.5052 - recon_loss: 136.1796 - accuracy: 0.7990 - kl_loss_metric: 7.3256
# Epoch 56/100
# 937/937 [==============================] - 29s 31ms/step - loss: 143.4292 - recon_loss: 136.1036 - accuracy: 0.7990 - kl_loss_metric: 7.3257
# Epoch 57/100
# 937/937 [==============================] - 53s 57ms/step - loss: 143.5116 - recon_loss: 136.1702 - accuracy: 0.7990 - kl_loss_metric: 7.3414
# Epoch 58/100
# 937/937 [==============================] - 27s 29ms/step - loss: 143.4294 - recon_loss: 136.0911 - accuracy: 0.7991 - kl_loss_metric: 7.3383
# Epoch 59/100
# 937/937 [==============================] - 17s 18ms/step - loss: 143.0186 - recon_loss: 135.6791 - accuracy: 0.7991 - kl_loss_metric: 7.3394
# Epoch 60/100
# 937/937 [==============================] - 16s 17ms/step - loss: 143.0808 - recon_loss: 135.7289 - accuracy: 0.7991 - kl_loss_metric: 7.3520
# Epoch 61/100
# 937/937 [==============================] - 16s 17ms/step - loss: 142.9287 - recon_loss: 135.5615 - accuracy: 0.7992 - kl_loss_metric: 7.3672
# Epoch 62/100
# 937/937 [==============================] - 17s 18ms/step - loss: 143.0924 - recon_loss: 135.7171 - accuracy: 0.7991 - kl_loss_metric: 7.3754
# Epoch 63/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.9543 - recon_loss: 135.5740 - accuracy: 0.7992 - kl_loss_metric: 7.3803
# Epoch 64/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.8846 - recon_loss: 135.4844 - accuracy: 0.7992 - kl_loss_metric: 7.4002
# Epoch 65/100
# 937/937 [==============================] - 17s 18ms/step - loss: 143.0868 - recon_loss: 135.7084 - accuracy: 0.7992 - kl_loss_metric: 7.3783
# Epoch 66/100
# 937/937 [==============================] - 20s 21ms/step - loss: 142.9199 - recon_loss: 135.5393 - accuracy: 0.7992 - kl_loss_metric: 7.3806
# Epoch 67/100
# 937/937 [==============================] - 35s 37ms/step - loss: 142.6771 - recon_loss: 135.2843 - accuracy: 0.7992 - kl_loss_metric: 7.3926
# Epoch 68/100
# 937/937 [==============================] - 16s 18ms/step - loss: 142.6599 - recon_loss: 135.2575 - accuracy: 0.7992 - kl_loss_metric: 7.4024
# Epoch 69/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.6855 - recon_loss: 135.2794 - accuracy: 0.7992 - kl_loss_metric: 7.4061
# Epoch 70/100
# 937/937 [==============================] - 18s 19ms/step - loss: 142.4658 - recon_loss: 135.0391 - accuracy: 0.7993 - kl_loss_metric: 7.4267
# Epoch 71/100
# 937/937 [==============================] - 16s 17ms/step - loss: 142.6954 - recon_loss: 135.2720 - accuracy: 0.7993 - kl_loss_metric: 7.4234
# Epoch 72/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.3752 - recon_loss: 134.9492 - accuracy: 0.7993 - kl_loss_metric: 7.4261
# Epoch 73/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.6385 - recon_loss: 135.2149 - accuracy: 0.7993 - kl_loss_metric: 7.4237
# Epoch 74/100
# 937/937 [==============================] - 18s 19ms/step - loss: 142.6525 - recon_loss: 135.2242 - accuracy: 0.7993 - kl_loss_metric: 7.4283
# Epoch 75/100
# 937/937 [==============================] - 28s 30ms/step - loss: 142.6979 - recon_loss: 135.2706 - accuracy: 0.7993 - kl_loss_metric: 7.4274
# Epoch 76/100
# 937/937 [==============================] - 15s 16ms/step - loss: 142.1708 - recon_loss: 134.7350 - accuracy: 0.7994 - kl_loss_metric: 7.4357
# Epoch 77/100
# 937/937 [==============================] - 16s 17ms/step - loss: 142.3359 - recon_loss: 134.8641 - accuracy: 0.7994 - kl_loss_metric: 7.4720
# Epoch 78/100
# 937/937 [==============================] - 17s 19ms/step - loss: 142.2395 - recon_loss: 134.7865 - accuracy: 0.7994 - kl_loss_metric: 7.4530
# Epoch 79/100
# 937/937 [==============================] - 26s 27ms/step - loss: 142.3827 - recon_loss: 134.9097 - accuracy: 0.7993 - kl_loss_metric: 7.4731
# Epoch 80/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.3718 - recon_loss: 134.9364 - accuracy: 0.7993 - kl_loss_metric: 7.4353
# Epoch 81/100
# 937/937 [==============================] - 17s 18ms/step - loss: 142.0548 - recon_loss: 134.5871 - accuracy: 0.7995 - kl_loss_metric: 7.4678
# Epoch 82/100
# 937/937 [==============================] - 24s 26ms/step - loss: 141.8835 - recon_loss: 134.4030 - accuracy: 0.7994 - kl_loss_metric: 7.4805
# Epoch 83/100
# 937/937 [==============================] - 17s 19ms/step - loss: 142.0367 - recon_loss: 134.5512 - accuracy: 0.7994 - kl_loss_metric: 7.4855
# Epoch 84/100
# 937/937 [==============================] - 16s 18ms/step - loss: 141.9572 - recon_loss: 134.4804 - accuracy: 0.7994 - kl_loss_metric: 7.4767
# Epoch 85/100
# 937/937 [==============================] - 17s 18ms/step - loss: 141.8804 - recon_loss: 134.4066 - accuracy: 0.7994 - kl_loss_metric: 7.4740
# Epoch 86/100
# 937/937 [==============================] - 24s 25ms/step - loss: 141.9541 - recon_loss: 134.4592 - accuracy: 0.7995 - kl_loss_metric: 7.4950
# Epoch 87/100
# 937/937 [==============================] - 20s 21ms/step - loss: 141.8558 - recon_loss: 134.3778 - accuracy: 0.7994 - kl_loss_metric: 7.4781
# Epoch 88/100
# 937/937 [==============================] - 25s 27ms/step - loss: 142.0231 - recon_loss: 134.5309 - accuracy: 0.7994 - kl_loss_metric: 7.4922
# Epoch 89/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.7740 - recon_loss: 134.2694 - accuracy: 0.7995 - kl_loss_metric: 7.5047
# Epoch 90/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.5611 - recon_loss: 134.0359 - accuracy: 0.7995 - kl_loss_metric: 7.5251
# Epoch 91/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.3725 - recon_loss: 133.8589 - accuracy: 0.7995 - kl_loss_metric: 7.5137
# Epoch 92/100
# 937/937 [==============================] - 26s 28ms/step - loss: 141.5533 - recon_loss: 134.0266 - accuracy: 0.7995 - kl_loss_metric: 7.5265
# Epoch 93/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.5339 - recon_loss: 134.0112 - accuracy: 0.7995 - kl_loss_metric: 7.5226
# Epoch 94/100
# 937/937 [==============================] - 25s 27ms/step - loss: 141.6144 - recon_loss: 134.0779 - accuracy: 0.7995 - kl_loss_metric: 7.5363
# Epoch 95/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.2698 - recon_loss: 133.7120 - accuracy: 0.7996 - kl_loss_metric: 7.5578
# Epoch 96/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.1278 - recon_loss: 133.6037 - accuracy: 0.7996 - kl_loss_metric: 7.5241
# Epoch 97/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.3579 - recon_loss: 133.8056 - accuracy: 0.7996 - kl_loss_metric: 7.5523
# Epoch 98/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.4425 - recon_loss: 133.8891 - accuracy: 0.7996 - kl_loss_metric: 7.5535
# Epoch 99/100
# 937/937 [==============================] - 17s 18ms/step - loss: 141.4908 - recon_loss: 133.9641 - accuracy: 0.7996 - kl_loss_metric: 7.5267
# Epoch 100/100
# 937/937 [==============================] - 16s 17ms/step - loss: 141.1609 - recon_loss: 133.6004 - accuracy: 0.7996 - kl_loss_metric: 7.5605
# dict_keys(['loss', 'recon_loss', 'accuracy', 'kl_loss_metric'])

# %% [markdown]
# ### Visualize the results (plot 1)
# Create plots that show the losses and metrics, the reconstruction quality of
# the trained network, and the generative quality of the network.

# %%
f, ax = plt.subplots(1,3, figsize = (20,5))

ax[0].plot(history.history['loss'], label = 'loss')
ax[0].plot(history.history['recon_loss'], label = 'Reconstruction loss')
ax[0].set_ylabel('reconstruction loss')
ax[0].set_xlabel('epoch')
ax[0].legend()

ax[1].plot(history.history['kl_loss_metric'], label = 'KL divergence')
ax[1].set_ylabel('KL loss')
ax[1].set_xlabel('epoch')
ax[1].legend()

ax[2].plot(history.history['accuracy'], label = 'Accuracy')
ax[2].set_ylabel('accuracy')
ax[2].set_xlabel('epoch')
ax[2].legend()

plt.show()

# %% [markdown]
# ### Prediction of test data (plot 2)

# %%
predict = autoencoder.predict(x_test/255.)
f, ax = plt.subplots(2, 7, figsize = (15,4))

# Testing the reconstruction quality of the network using the Test Images 
for i in range(7):
    ax[0,i].imshow(x_test[i+100])
    ax[1,i].imshow(predict[i+100,:,:,0])
# Out:
# 313/313 [==============================] - 1s 3ms/step

# %% [markdown]
# ### Testing the generative quality of the network (plot 3)

# %%
x_axis = np.linspace(-1, 1, 10)
y_axis = np.linspace(-1, 1, 10)
figure = np.zeros((28 * 10, 28 * 10))

# loop through each number for decoding
for i_x, x in enumerate(x_axis):
    for i_y, y in enumerate(y_axis):
        latent = np.array([[x, y]])
        #print(latent)
        generated_image = decoder.predict(latent)[0] # decode the numbers
        figure[i_x*28:(i_x+1)*28, i_y*28:(i_y+1)*28,] = generated_image[:,:,-1]

plt.figure(figsize=(15, 15))
plt.imshow(figure, extent=[1,-1,1,-1])
plt.show()
# Out:
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 7ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 9ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step
# 1/1 [==============================] - 0s 8ms/step

# %% [markdown]
# ### Task: Visualize the latent space (if latent_dim > 2 then by using T_SNE) (plot 4)
# #### Describe the latent space with respect to its structure.
#
# Remember: t-SNE is stochastic and therefore the results may appear slightly different every time it is re-run. So don't worry.

# %%
# add your code section here !
# T-SNE plot of the latent space
import numpy as np
from sklearn.manifold import TSNE

# Get the latent space for the train data
latent_space = encoder.predict(x_train)

# Run TSNE on the latent space
tsne = TSNE(n_components=2, random_state=0)
latent_tsne = tsne.fit_transform(latent_space[0])

# Plot the TSNE results
plt.figure(figsize=(10, 10))
plt.scatter(latent_tsne[:, 0], latent_tsne[:, 1], c=y_train, cmap='tab10')
plt.colorbar()
plt.title('TSNE plot of the latent space for the training data')
plt.show()
# Out:
# 1875/1875 [==============================] - 2s 1ms/step

# %%
# add your code section here !
# T-SNE plot of the latent space
import numpy as np
from sklearn.manifold import TSNE

# Get the latent space for the train data
latent_space = encoder.predict(x_test)

# Run TSNE on the latent space
tsne = TSNE(n_components=2, random_state=0)
latent_tsne = tsne.fit_transform(latent_space[0])

# Plot the TSNE results
plt.figure(figsize=(10, 10))
plt.scatter(latent_tsne[:, 0], latent_tsne[:, 1], c=y_test, cmap='tab10')
plt.colorbar()
plt.title('TSNE plot of the latent space for the test data')
plt.show()
# Out:
# 313/313 [==============================] - 0s 1ms/step
